# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome(executable_path='chromedriver')
driver.implicitly_wait(time_to_wait=1)

URL = 'https://www.baristapaulbassett.co.kr/store/Store.pb'
driver.get(URL)
element = driver.find_elements_by_css_selector('#shopList > li')
address_list =[]

for shop in element:
    address =shop.find_element_by_tag_name('address')
    print(address.text)
#URL = 'https://www.naver.com'
#driver.get(URL)
#element = driver.find_element_by_id('query') # 아이디값으로 찾음
#element.send_keys('test') # test 라는 키워드를
#element.send_keys(Keys.RETURN) # 엔터해줌

#for i in range(1,11,1):
 #   if i == 2:
   #     URL1 = 'https://search.naver.com/search.naver?display=15&f=&filetype=0&page='+str(i)+'&query='+str(keyword)+'&research_url=&sm=tab_pge&start=1&where=web'
  #  else:
    #    URL1 = 'https://search.naver.com/search.naver?display=15&f=&filetype=0&page='+str(i)+'&query='+str(keyword)+'&research_url=&sm=tab_pge&start='+str(i*16)+'&where=web'
     #   time.sleep(1)    
      #  driver.get(URL1)
# Out:
# <ipython-input-34-224e35dc780b>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   element = driver.find_elements_by_css_selector('#shopList > li')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-224e35dc780b> in <module>
#       5 driver.get(URL)
#       6 element = driver.find_elements_by_css_selector('#shopList > li')
# ----> 7 print(element.text)
#       8 address_list =[]
#       9
#
# AttributeError: 'list' object has no attribute 'text'

# %%
driver = webdriver.Chrome(executable_path='chromedriver')
driver.implicitly_wait(time_to_wait=1)
address_list =[]
for i in range(1,16,1):
    if i == 1:
        URL1 = 'https://www.10000lab.com/59'
    else:
        URL1 = 'https://www.10000lab.com/59/?sort=TIME&keyword_type=all&page='+(str)(i)+''
        time.sleep(1)    
    driver.get(URL1)
    adress=driver.find_elements_by_class_name('adress')
    for i in range(10):
        address = adress[i]
        print(address.text)
        
    print("")
# Out:
# <ipython-input-49-8876e651d3c4>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   adress=driver.find_elements_by_class_name('adress')
# 서울특별시 관악구 신림동 신림동7길
# 경기도 광주시 경충대로
# 대구광역시 북구 연경동
# 경상남도 창원시 마산합포구 3·15대로
# 인천광역시 서구 청라동 커낼로
# 경기도 화성시 동탄첨단산업1로
# 경기도 용인시 기흥구 농서동 산24
# 경상북도 영양군 영양읍 여남길 1
# 서울특별시 금천구 가산동 가산디지털1로
# 경기도 오산시 세마동 독산성로
#
# 부산광역시 해운대구 재송동 센텀중앙로 97
# 경기도 하남시 학암동
# 충청북도 제천시 장락동 장락로
# 서울특별시 강남구 대치동 삼성로72길
# 경상남도 창원시 성산구 상남동 단정로 23
# 인천광역시 남동구 구월동 인주대로 611
# 서울특별시 금천구 가산동 가산디지털1로 168
# 경상남도 창원시 마산합포구 구산면 수정리
# 경기도 과천시 별양동 별양상가1로 38
# 경기도 평택시 비전동 1098-1
#
# 대구광역시 수성구 범물2동 지범로48길
# 경기도 성남시 수정구 고등동 청계산로
# 부산광역시 동래구 명륜동 명륜로 129
# 동탄 대로 시범 길 148-16, 동탄면 화성시
# 서울특별시 성동구 도선동 46
# 서울특별시 송파구 가락본동 중대로23길
# 전라남도 순천시 연향동 연향상가7길 26
# 서울특별시 서초구 서초4동 서초중앙로 146
# 경상남도 김해시 진영읍 김해대로334번길 9
# 경기도 남양주시 진접읍 해밀예당2로
#
# 서울특별시 서초구 서초대로 13
# 서울특별시 광진구 중곡동 용마산로 107
# 서울특별시 영등포구 여의도동 국제금융로2길 32 여의도파이낸스타워
# 경기도 시흥시 장현동 533-8
# ...
